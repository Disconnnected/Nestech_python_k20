# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("resource\EPL_stat_player_2018_2019.csv")
df.head()
# Out:
#          full_name  age    position       Current Club  \
# 0  Aaron Cresswell   32    Defender    West Ham United
# 1     Aaron Lennon   35  Midfielder            Burnley
# 2       Aaron Mooy   32  Midfielder  Huddersfield Town
# 3     Aaron Ramsey   31  Midfielder            Arsenal
# 4       Aaron Rowe   22     Forward  Huddersfield Town
#
#    minutes_played_overall  minutes_played_home  minutes_played_away  \
# 0                    1589                  888                  701
# 1                    1217                  487                  730
# 2                    2327                 1190                 1137
# 3                    1327                  689                  638
# 4                      69                   14                   55
#
#   nationality  appearances_overall  appearances_home  ...  \
# 0     England                   20                11  ...
# 1     England                   16                 7  ...
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df["Current Club"].unique()
man_utd = df[df["Current Club"] == "Manchester United"]
man_utd = man_utd[man_utd["position"] == "Forward"]
man_utd = man_utd[["full_name","goals_overall", "goals_home", "goals_away"]]
man_utd
# Out:
#            full_name  goals_overall  goals_home  goals_away
# 30    Alexis Sanchez              1           1           0
# 55   Anthony Martial             10           4           6
# 368  Marcus Rashford             10           4           6
# 472    Romelu Lukaku             12           4           8
# 525     Tahith Chong              0           0           0

# %%
man_utd.plot()
# Out:
# <Axes: >
